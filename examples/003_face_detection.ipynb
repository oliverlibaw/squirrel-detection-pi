# %% [markdown]
# ## Face Detection Inference with DeGirum PySDK
#
# This notebook demonstrates face detection using DeGirum PySDK on Hailo hardware.

# %%
import degirum as dg, degirum_tools

inference_host_address = "@local"
zoo_url = "degirum/hailo"
token = '' 
device_type = "HAILORT/HAILO8L"

# Choose the model name 
face_det_model_name = "scrfd_10g--640x640_quant_hailort_hailo8l_1"
# face_det_model_name = "scrfd_2.5g--640x640_quant_hailort_hailo8l_1"
# face_det_model_name = "scrfd_500m--640x640_quant_hailort_hailo8l_1"
# face_det_model_name = "retinaface_mobilenet--736x1280_quant_hailort_hailo8l_1"
# face_det_model_name = "yolov8n_relu6_widerface_kpts--640x640_quant_hailort_hailo8l_1"

# choose image source
image_source = "../assets/ThreePersons.jpg"

# load AI model
model = dg.load_model(
    model_name=face_det_model_name,
    inference_host_address=inference_host_address,
    zoo_url=zoo_url,
    token=token,
    device_type=device_type
    
)

# perform AI model inference on given image source
print(f" Running inference using '{face_det_model_name}' on image source '{image_source}'")
inference_result = model(image_source)

# print('Inference Results \n', inference_result)  # numeric results
print(inference_result)
print("Press 'x' or 'q' to stop.")

# show results of inference
with degirum_tools.Display("AI Camera") as output_display:
    output_display.show_image(inference_result.image_overlay)
# Out:
#  Running inference using 'scrfd_10g--640x640_quant_hailort_hailo8l_1' on image source '../assets/ThreePersons.jpg'
# - bbox: [170.61256408691406, 81.03021240234375, 216.30392456054688, 139.35958862304688]
#   category_id: 0
#   label: face
#   landmarks:
#   - category_id: 0
#     connect: []
#     landmark: [181.7291259765625, 99.88185119628906]
#     score: 0.8352941870689392
#   - category_id: 1
#     connect: []
#     landmark: [197.7060546875, 107.87031555175781]
#     score: 0.8352941870689392
#   - category_id: 2
#     connect: []
#     landmark: [179.4467010498047, 111.86456298828125]
#     score: 0.8352941870689392
#   - category_id: 3
#     connect: []
#     landmark: [174.88186645507812, 119.28242492675781]
#     score: 0.8352941870689392
#   - category_id: 4
#     connect: []
#     landmark: [188.00576782226562, 126.12966918945312]
#     score: 0.8352941870689392
#   score: 0.8352941870689392
# - bbox: [387.32135009765625, 64.54412841796875, 434.470947265625, 121.415283203125]
#   category_id: 0
#   label: face
#   landmarks:
#   - category_id: 0
#     connect: []
#     landmark: [400.5936279296875, 83.8818359375]
#     score: 0.8156863451004028
#   - category_id: 1
#     connect: []
#     landmark: [412.57635498046875, 94.15272521972656]
#     score: 0.8156863451004028
#   - category_id: 2
#     connect: []
#     landmark: [394.8875732421875, 95.86454772949219]
#     score: 0.8156863451004028
#   - category_id: 3
#     connect: []
#     landmark: [392.0345764160156, 101.57058715820312]
#     score: 0.8156863451004028
#   - category_id: 4
#     connect: []
#     landmark: [402.3054504394531, 109.55906677246094]
#     score: 0.8156863451004028
#   score: 0.8156863451004028
# - bbox: [548.7796020507812, 69.44549560546875, 598.3595581054688, 117.0811767578125]
#   category_id: 0
#   label: face
#   landmarks:
#   - category_id: 0
#     connect: []
#     landmark: [572.5763549804688, 83.85879516601562]
#     score: 0.7686275243759155
#   - category_id: 1
#     connect: []
#     landmark: [582.8472290039062, 98.12391662597656]
#     score: 0.7686275243759155
#   - category_id: 2
#     connect: []
#     landmark: [569.1527099609375, 96.412109375]
#     score: 0.7686275243759155
#   - category_id: 3
#     connect: []
#     landmark: [558.8818359375, 96.412109375]
#     score: 0.7686275243759155
#   - category_id: 4
#     connect: []
#     landmark: [566.8703002929688, 107.82421875]
#     score: 0.7686275243759155
#   score: 0.7686275243759155
#
# Press 'x' or 'q' to stop.
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/pi5two/hailo_examples/degirum_env/lib/python3.11/site-packages/cv2/qt/plugins"
